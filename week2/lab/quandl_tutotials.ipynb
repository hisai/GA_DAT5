# %%
import numpy as np
import pandas as pd
import matplotlib as plt 
# display plots in the notebook
# %matplotlib inline

import quandl
quandl.ApiConfig.api_key = "7b3zG3xpXy4aDrGXFdvF"
#data = quandl.get("WIFI/TLSA")
data = quandl.get("EIA/PET_RWTC_D", start_date="1/6/2017", end_date='20/8/2017')
data.plot()
